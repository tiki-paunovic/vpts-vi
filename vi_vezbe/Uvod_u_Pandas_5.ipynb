# %% [markdown]
# # Uvod u Python Pandas
# ## Peti deo
#
# ## Filtriranje podataka

# %%
import pandas as pd
df = pd.read_csv('../datasets/bikes.csv')
df.head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St      41.90096
# 1       -87.641170              31.0     Wells St & Walton St      41.89993
# 2       -87.653497              15.0  Dearborn St & Monroe St      41.88132
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# ...

# %% [markdown]
# Odrediti u kojim redovima putovanje traje duže od 1000 sekundi. Da bismo napravili poređenje, biramo kolonu **tripduration** kao niz i upoređujemo je sa celim brojem 1000.

# %%
uslov = df['tripduration']  > 1000
uslov.head(3)
# Out:
# 0    False
# 1    False
# 2     True
# Name: tripduration, dtype: bool

# %% [markdown]
# Kada napišemo df['tripduration'] > 1000, pandas upoređuje svaku vrednost u koloni tripduration sa 1000. Vraća novu seriju iste dužine kao tripduartion sa logičkim vrednostima koje odgovaraju ishodu poređenja.

# %%
len(uslov)
# Out:
# 50089

# %%
len(df)
# Out:
# 50089

# %%
df[uslov].head(3)
# Out:
#     trip_id    usertype gender            starttime             stoptime  \
# 2     10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8     21028  Subscriber   Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 10    24383  Subscriber   Male  2013-07-04 17:17:00  2013-07-04 17:42:00
#
#     tripduration             from_station_name  latitude_start  \
# 2           1040  Sheffield Ave & Kingsbury St       41.909592
# 8           1300  Clinton St & Washington Blvd       41.883380
# 10          1523           Morgan St & 18th St       41.858086
#
#     longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 2        -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 8        -87.641170              31.0    Wood St & Division St     41.903320
# 10       -87.651073              15.0   Damen Ave & Pierce Ave     41.909396
#
#     longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# ...

# %% [markdown]
# Koliko imamo redova čije je trajanje putovanja veće od 1000?
# Da bismo odgovorili na ovo pitanje, dodelimo rezultat logičke selekcije promenljivoj, a zatim uporedimo broj redova između nje i originalnog DataFrame-a.

# %%
bikes_duration_1000 = df[uslov]
bikes_duration_1000
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 2         10927  Subscriber    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8         21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 10        24383  Subscriber    Male  2013-07-04 17:17:00  2013-07-04 17:42:00
# 11        24673  Subscriber    Male  2013-07-04 18:13:00  2013-07-04 18:42:00
# 12        26214  Subscriber    Male  2013-07-05 10:02:00  2013-07-05 10:40:00
# ...         ...         ...     ...                  ...                  ...
# 50058  17525403  Subscriber  Female  2017-12-23 13:48:00  2017-12-23 14:14:00
# 50077  17533484  Subscriber    Male  2017-12-29 09:13:00  2017-12-29 09:53:00
# 50080  17534057  Subscriber    Male  2017-12-29 15:28:00  2017-12-29 15:51:00
# 50083  17534831  Subscriber    Male  2017-12-30 11:36:00  2017-12-30 11:55:00
# 50084  17534938  Subscriber    Male  2017-12-30 13:07:00  2017-12-30 13:34:00
#
# ...

# %%
len(df)
# Out:
# 50089

# %%
len(bikes_duration_1000)
# Out:
# 10178

# %% [markdown]
# Izračunali smo da je 20% vožnji duže od 1000 sekundi.

# %%
len(bikes_duration_1000) / len(df)
# Out:
# 0.20319830701351593

# %% [markdown]
# ### Logički izbor u jednom redu

# %%
df[df['tripduration'] > 1000].head(3)
# Out:
#     trip_id    usertype gender            starttime             stoptime  \
# 2     10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8     21028  Subscriber   Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 10    24383  Subscriber   Male  2013-07-04 17:17:00  2013-07-04 17:42:00
#
#     tripduration             from_station_name  latitude_start  \
# 2           1040  Sheffield Ave & Kingsbury St       41.909592
# 8           1300  Clinton St & Washington Blvd       41.883380
# 10          1523           Morgan St & 18th St       41.858086
#
#     longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 2        -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 8        -87.641170              31.0    Wood St & Division St     41.903320
# 10       -87.651073              15.0   Damen Ave & Pierce Ave     41.909396
#
#     longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# ...

# %% [markdown]
# Primer: pronaći sve vožnje koje su se desile kada je vreme bilo oblačno. Koristimo == operator da testiramo jednakost i ponovo prosleđujemo ovu promenljivu u zagrade čime se završava naš izbor.

# %%
uslov = df['events'] == 'cloudy'
df[uslov].head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 6    18880  Subscriber   Male  2013-07-02 17:47:00  2013-07-02 17:56:00
# 7    19689  Subscriber   Male  2013-07-03 09:07:00  2013-07-03 09:16:00
# 8    21028  Subscriber   Male  2013-07-03 15:21:00  2013-07-03 15:42:00
#
#    tripduration             from_station_name  latitude_start  \
# 6           565        Clark St & Randolph St       41.884576
# 7           505       State St & Van Buren St       41.877181
# 8          1300  Clinton St & Washington Blvd       41.883380
#
#    longitude_start  dpcapacity_start                  to_station_name  \
# 6       -87.631890              31.0  Ravenswood Ave & Irving Park Rd
# 7       -87.627844              27.0       Franklin St & Jackson Blvd
# 8       -87.641170              31.0            Wood St & Division St
#
#    latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# ...

# %%
df[df['events'] == 'cloudy'].head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 6    18880  Subscriber   Male  2013-07-02 17:47:00  2013-07-02 17:56:00
# 7    19689  Subscriber   Male  2013-07-03 09:07:00  2013-07-03 09:16:00
# 8    21028  Subscriber   Male  2013-07-03 15:21:00  2013-07-03 15:42:00
#
#    tripduration             from_station_name  latitude_start  \
# 6           565        Clark St & Randolph St       41.884576
# 7           505       State St & Van Buren St       41.877181
# 8          1300  Clinton St & Washington Blvd       41.883380
#
#    longitude_start  dpcapacity_start                  to_station_name  \
# 6       -87.631890              31.0  Ravenswood Ave & Irving Park Rd
# 7       -87.627844              27.0       Franklin St & Jackson Blvd
# 8       -87.641170              31.0            Wood St & Division St
#
#    latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# ...

# %% [markdown]
# ### Vežbe
# Za sledeće vežbe koristite skup podataka movie.csv sa skupom naslova kao indeksom (title).

# %% [markdown]
# ### Vežba 1
# Izaberite sve filmove u kojima je Johnny Depp `glumac1`. U koliko od ovih filmova je glumio?

# %%
import pandas as pd
df_filmovi = pd.read_csv('../datasets/movie.csv', index_col='title')
df_filmovi.head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# ...

# %%
uslov = df_filmovi['actor1'] == 'Johnny Depp'
depp_filmovi = df_filmovi[uslov]
depp_filmovi.head(3)
# Out:
#                                               year  color content_rating  \
# title
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Pirates of the Caribbean: Dead Man's Chest  2006.0  Color          PG-13
# The Lone Ranger                             2013.0  Color          PG-13
#
#                                             duration   director_name  \
# title
# Pirates of the Caribbean: At World's End       169.0  Gore Verbinski
# Pirates of the Caribbean: Dead Man's Chest     151.0  Gore Verbinski
# The Lone Ranger                                150.0  Gore Verbinski
#
#                                             director_fb       actor1  \
# title
# Pirates of the Caribbean: At World's End          563.0  Johnny Depp
# Pirates of the Caribbean: Dead Man's Chest        563.0  Johnny Depp
# The Lone Ranger                                   563.0  Johnny Depp
#
#                                             actor1_fb         actor2  \
# title
# ...

# %%
depp_filmovi.shape
# Out:
# (36, 21)

# %% [markdown]
# ### Vežba 2
# Izaberite filmove sa IMDB score ocenom većom od 9.

# %%
uslov = df_filmovi['imdb_score'] > 9
df_filmovi[uslov]
# Out:
#                             year  color content_rating  duration  \
# title
# The Shawshank Redemption  1994.0  Color              R     142.0
# Towering Inferno             NaN  Color            NaN      65.0
# Dekalog                      NaN  Color          TV-MA      55.0
# The Godfather             1972.0  Color              R     175.0
# Kickboxer: Vengeance      2016.0    NaN            NaN      90.0
#
#                                  director_name  director_fb          actor1  \
# title
# The Shawshank Redemption        Frank Darabont          0.0  Morgan Freeman
# Towering Inferno                John Blanchard          0.0    Martin Short
# Dekalog                                    NaN          NaN  Krystyna Janda
# The Godfather             Francis Ford Coppola          0.0       Al Pacino
# Kickboxer: Vengeance            John Stockwell        134.0    Matthew Ziff
#
#                           actor1_fb           actor2  actor2_fb  ...  \
# ...

# %% [markdown]
# ### Vežba 3
# Napišite funkciju koja prihvata jedan parametar da biste pronašli broj filmova za datu ocenu sadržaja. Koristite ovu funkciju da biste pronašli broj filmova ocenjene sa „R“, „PG-13“ i „PG“.

# %%
def count_rating(rating):
    uslov = df_filmovi['content_rating'] == rating
    count = len(df_filmovi[uslov])
    return 'Ima {} filmova koji su ocenjeni sa {}'.format(count, rating)

# %%
count_rating('R')
# Out:
# 'Ima 2067 filmova koji su ocenjeni sa R'

# %%
count_rating('PG-13')
# Out:
# 'Ima 1411 filmova koji su ocenjeni sa PG-13'

# %%
count_rating('PG')
# Out:
# 'Ima 686 filmova koji su ocenjeni sa PG'

# %% [markdown]
# ## Višestruki uslovi

# %% [markdown]
# Pronaći sve vožnje duže od 1000 sekundi kada je bilo oblačno.
# Ovaj upit ima dva uslova - trajanje putovanja veće od 1000 i oblačno vreme.

# %%
import pandas as pd
df = pd.read_csv('../datasets/bikes.csv')
df.head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St      41.90096
# 1       -87.641170              31.0     Wells St & Walton St      41.89993
# 2       -87.653497              15.0  Dearborn St & Monroe St      41.88132
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# ...

# %%
uslov1 = df['tripduration'] > 1000
uslov2 = df['events'] == 'cloudy'
uslov = uslov1 & uslov2
df[uslov].head(3)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 8     21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 18    40924  Subscriber    Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 80    90932  Subscriber  Female  2013-07-22 07:59:00  2013-07-22 08:19:00
#
#     tripduration             from_station_name  latitude_start  \
# 8           1300  Clinton St & Washington Blvd       41.883380
# 18          5396       Canal St & Jackson Blvd       41.878114
# 80          1224    Lincoln Ave & Armitage Ave       41.918273
#
#     longitude_start  dpcapacity_start         to_station_name  latitude_end  \
# 8        -87.641170              31.0   Wood St & Division St     41.903320
# 18       -87.639971              35.0         Millennium Park     41.881032
# 80       -87.638116              19.0  Dearborn St & Adams St     41.879356
#
#     longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# ...

# %% [markdown]
# ### Više uslova u jednom redu

# %%
df[(df['tripduration'] > 1000) & (df['events'] == 'cloudy')].head(3)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 8     21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 18    40924  Subscriber    Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 80    90932  Subscriber  Female  2013-07-22 07:59:00  2013-07-22 08:19:00
#
#     tripduration             from_station_name  latitude_start  \
# 8           1300  Clinton St & Washington Blvd       41.883380
# 18          5396       Canal St & Jackson Blvd       41.878114
# 80          1224    Lincoln Ave & Armitage Ave       41.918273
#
#     longitude_start  dpcapacity_start         to_station_name  latitude_end  \
# 8        -87.641170              31.0   Wood St & Division St     41.903320
# 18       -87.639971              35.0         Millennium Park     41.881032
# 80       -87.638116              19.0  Dearborn St & Adams St     41.879356
#
#     longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# ...

# %% [markdown]
# ### Vežba 4
# U skupu podataka movie.csv izaberite sve filmove iz 1970-ih.

# %%
df_filmovi.head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# ...

# %%
uslov1= df_filmovi['year'] >= 1970
uslov2= df_filmovi['year'] <= 1979
uslov = uslov1 & uslov2
df_filmovi[uslov].head(3)
# Out:
#                  year            color content_rating  duration  \
# title
# All That Jazz  1979.0            Color              R     123.0
# Superman       1978.0            Color             PG     188.0
# Solaris        1972.0  Black and White             PG     115.0
#
#                   director_name  director_fb            actor1  actor1_fb  \
# title
# All That Jazz         Bob Fosse        189.0      Roy Scheider      813.0
# Superman         Richard Donner        503.0     Marlon Brando    10000.0
# Solaris        Andrei Tarkovsky          0.0  Donatas Banionis       29.0
#
#                             actor2  actor2_fb  ... actor3_fb        gross  \
# title                                          ...
# All That Jazz           Ben Vereen      388.0  ...      87.0          NaN
# Superman             Margot Kidder      593.0  ...     467.0  134218018.0
# Solaris        Anatoliy Solonitsyn       29.0  ...      12.0          NaN
#
# ...

# %% [markdown]
# ### Vežba 5
# Izaberite sve filmove iz 1970-ih koji su imali IMDB ocene veće od 8.

# %%
uslov1= df_filmovi['year'] >= 1970
uslov2= df_filmovi['year'] <= 1979
uslov3 = df_filmovi['imdb_score'] > 8

uslov = uslov1 & uslov2 & uslov3
df_filmovi[uslov].head(3)
# Out:
#                    year            color content_rating  duration  \
# title
# Solaris          1972.0  Black and White             PG     115.0
# Apocalypse Now   1979.0            Color              R     289.0
# The Deer Hunter  1978.0            Color              R     183.0
#
#                         director_name  director_fb            actor1  \
# title
# Solaris              Andrei Tarkovsky          0.0  Donatas Banionis
# Apocalypse Now   Francis Ford Coppola          0.0     Harrison Ford
# The Deer Hunter        Michael Cimino        517.0    Robert De Niro
#
#                  actor1_fb               actor2  actor2_fb  ... actor3_fb  \
# title                                                       ...
# Solaris               29.0  Anatoliy Solonitsyn       29.0  ...      12.0
# Apocalypse Now     11000.0        Marlon Brando    10000.0  ...    3000.0
# The Deer Hunter    22000.0         Meryl Streep    11000.0  ...     652.0
#
# ...

# %% [markdown]
# ### Vežba 6
# Izaberite filmove koji su ocenjeni sa R, PG-13 ili PG.

# %%
uslov1= df_filmovi['content_rating'] == 'R'
uslov2= df_filmovi['content_rating'] == 'PG-13'
uslov3= df_filmovi['content_rating'] == 'PG'

uslov = uslov1 | uslov2 | uslov3
df_filmovi[uslov].head()
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
# John Carter                               2012.0  Color          PG-13
#
#                                           duration      director_name  \
# title
# Avatar                                       178.0      James Cameron
# Pirates of the Caribbean: At World's End     169.0     Gore Verbinski
# Spectre                                      148.0         Sam Mendes
# The Dark Knight Rises                        164.0  Christopher Nolan
# John Carter                                  132.0     Andrew Stanton
#
#                                           director_fb           actor1  \
# title
# ...
